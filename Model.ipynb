# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df=pd.read_csv('farm_dataset.csv')

# %%
df.head()
# Out:
#     Crop Soil_Type    N   P   K   pH  Rainfall_mm  Temperature_C  Humidity_%  \
# 0   Rice     Sandy  100  36  67  6.0          150             26          64
# 1  Maize      Clay   89  35  42  7.1          139             34          68
# 2  Maize     Loamy   84  50  30  7.0           43             21          59
# 3  Wheat     Loamy   85  28  58  6.7           25             31          75
# 4  Maize     Sandy   45  50  56  5.8          126             25          55
#
#    Irrigation_mm Fertilizer_Type  Fertilizer_Amount_kg  Yield_q_per_acre
# 0            178            Urea                    91              25.6
# 1            237             DAP                    86              23.6
# 2            108            Urea                    97              14.2
# 3            170             DAP                    97              13.7
# 4             64             DAP                    64              13.2

# %%
df.info()
df.describe(include='all')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 13 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Crop                  200 non-null    object
#  1   Soil_Type             200 non-null    object
#  2   N                     200 non-null    int64
#  3   P                     200 non-null    int64
#  4   K                     200 non-null    int64
#  5   pH                    200 non-null    float64
#  6   Rainfall_mm           200 non-null    int64
#  7   Temperature_C         200 non-null    int64
#  8   Humidity_%            200 non-null    int64
#  9   Irrigation_mm         200 non-null    int64
#  10  Fertilizer_Type       200 non-null    object
#  11  Fertilizer_Amount_kg  200 non-null    int64
#  12  Yield_q_per_acre      200 non-null    float64
# dtypes: float64(2), int64(8), object(3)
# memory usage: 20.4+ KB
# ...

# %%
print("Missing values per column:")
print(df.isnull().sum())
# Out:
# Missing values per column:
# Crop                    0
# Soil_Type               0
# N                       0
# P                       0
# K                       0
# pH                      0
# Rainfall_mm             0
# Temperature_C           0
# Humidity_%              0
# Irrigation_mm           0
# Fertilizer_Type         0
# Fertilizer_Amount_kg    0
# Yield_q_per_acre        0
# dtype: int64

# %%
print("Crop distribution:")
print(df['Crop'].value_counts())
# Out:
# Crop distribution:
# Crop
# Maize        47
# Sugarcane    43
# Rice         38
# Wheat        37
# Cotton       35
# Name: count, dtype: int64

# %%
plt.hist(df['Yield_q_per_acre'], bins=15)
plt.title('Yield Distribution')
plt.xlabel('Yield (q per acre)')
plt.ylabel('Frequency')
plt.show()

# %%
# Example: drop rows with missing values
df = df.dropna()

# Or impute with mean/median/mode if necessary
# df['column'] = df['column'].fillna(df['column'].mean())

# %%
from sklearn.preprocessing import LabelEncoder

le_crop = LabelEncoder()
df['Crop_encoded'] = le_crop.fit_transform(df['Crop'])

le_soil = LabelEncoder()
df['Soil_encoded'] = le_soil.fit_transform(df['Soil_Type'])

le_fert = LabelEncoder()
df['Fertilizer_encoded'] = le_fert.fit_transform(df['Fertilizer_Type'])
